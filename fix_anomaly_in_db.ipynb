# %%
"""
This script fixes an anomalous value in the statistics of my water meter sensor.
It replaces the anomalous values by interpolated values and adjusted both the 
long term as well as the short term statistics tables

Before executing the script, stop you homeassistant service:
ssh jan@192.168.1.25
sudo systemctl stop home-assistant@homeassistant.service 

Don't forget to start afterwards:
sudo systemctl start home-assistant@homeassistant.service 
"""
# Out:
# "\nThis script fixes an anomalous value in the statistics of my water meter sensor.\nIt replaces the anomalous values by interpolated values and adjusted both the \nlong term as well as the short term statistics tables\n\nBefore executing the script, stop you homeassistant service:\nssh jan@192.168.1.25\nsudo systemctl stop home-assistant@homeassistant.service \n\nDon't forget to start afterwards:\nsudo systemctl start home-assistant@homeassistant.service \n"

# %%
hass_ip="192.168.1.25" # change this to the ip of you home assistant installation

# %% [markdown]
# # Retrieve database from home assistant server

# %%
! scp homeassistant@{hass_ip}:/home/homeassistant/.homeassistant/home-assistant_v2.db .
! mkdir -p backup
! cp home-assistant_v2.db backup # make a backup
# Out:
# home-assistant_v2.db                          100%  590MB  10.0MB/s   00:59

# %% [markdown]
# # Connect to DB

# %%
import pandas
import sqlite3
import pandas
from IPython.display import display

pandas.options.plotting.backend = "plotly"

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("home-assistant_v2.db")

# %% [markdown]
# # Find watermeter

# %%
df=pandas.read_sql_query(f"select * FROM statistics_meta --where unit_of_measurement='EUR';", con)
df.head()
# Out:
#    id             statistic_id    source unit_of_measurement  has_mean  \
# 0   1  sensor.nibe_93714_40067  recorder                  °C         1
# 1   2  sensor.nibe_93714_40014  recorder                  °C         1
# 2   3  sensor.nibe_93714_40013  recorder                  °C         1
# 3   4  sensor.nibe_93714_40004  recorder                  °C         1
# 4   5  sensor.nibe_93714_40083  recorder                   A         1
#
#    has_sum  name
# 0        0  None
# 1        0  None
# 2        0  None
# 3        0  None
# 4        0  None

# %%
df[df['statistic_id'].str.contains('water')]
# Out:
#     id                            statistic_id    source unit_of_measurement  \
# 80  81       sensor.watermeter_value_from_json  recorder                  m³
# 81  82  sensor.watermeter_value_from_json_cost  recorder                 EUR
#
#     has_mean  has_sum  name
# 80         0        1  None
# 81         0        1  None

# %% [markdown]
# # Find anomaly

# %%
sensor_id=81
# sensor_id=82

df=pandas.read_sql_query(f"select * FROM statistics where metadata_id={sensor_id};", con)
display(df.tail())
df=df.set_index('start')
fig=df[['state','sum']].plot()
fig.show()

df=pandas.read_sql_query(f"select * FROM statistics_short_term where metadata_id={sensor_id};", con)
display(df.tail())
df=df.set_index('start')
fig=df[['state','sum']].plot()
fig.show()

# %% [markdown]
# # Fix anomaly

# %%
for sensor_id in [81,82]:
    threshold = 120  # derived from the graphs, coincidence that it applies for both sensors

    for table in ["statistics", "statistics_short_term"]:
        # read what is currently in the db
        df = pandas.read_sql_query(
            f"select * FROM {table} where metadata_id = {sensor_id};", con
        )
        # set anomalous value to NA
        df.loc[df["state"] > threshold, "state"] = pandas.NA
        # fill NA by interpolating
        df["state"] = df["state"].interpolate(method="linear").fillna(0)
        if sensor_id == 81:
            df["sum"] = df["state"] - 100.058
        elif sensor_id == 82:
            if table == "statistics":
                df["sum"] = df["state"].diff(periods=1).apply(lambda x: max(x,0)).fillna(0).cumsum()
            elif table == "statistics_short_term":
                df["sum"] = df["state"].diff(periods=1).apply(lambda x: max(x,0)).fillna(0).cumsum() # missing the offset
                # calculating the offset by finding the first common date between
                # short term statistics and long term statistics
                df_long = pandas.read_sql_query(
                    f"select * FROM statistics where metadata_id = {sensor_id};", con
                )
                common_dt = df.loc[pandas.to_datetime(df["start"]).dt.minute == 0, "start"].min()
                offset = (
                    df_long.loc[df_long["start"] == common_dt, "sum"].iloc[0]
                    - df.loc[df["start"] == common_dt, "sum"].iloc[0]
                )
                df["sum"]  = df["sum"] + offset

        # drop all existing rows with same metadata_id from the sensor
        # because i will recreate all statistics for that sensor
        # instead of updating the sum value which one would do if you would like
        # to keep the existing statistics

        stmnt = f"""DELETE FROM {table}
                    WHERE metadata_id={sensor_id};"""
        cur = con.cursor()
        cur.execute(stmnt)
        con.commit()

        # insert new data into table
        df.to_sql(
            table, con, schema=None, if_exists="append", index=False,
        )

# %% [markdown]
# # Check if fixed

# %%
sensor_id=81
# sensor_id=82

df=pandas.read_sql_query(f"select * FROM statistics where metadata_id={sensor_id};", con)
display(df.tail())
df=df.set_index('start')
fig=df[['state','sum']].plot()
fig.show()

df=pandas.read_sql_query(f"select * FROM statistics_short_term where metadata_id={sensor_id};", con)
display(df.tail())
df=df.set_index('start')
fig=df[['state','sum']].plot()
fig.show()
# Out:
#          id                     created                       start  mean  \
# 921  433576  2023-02-25 18:00:10.685034  2023-02-25 17:00:00.000000  None
# 922  433683  2023-02-25 19:00:10.676403  2023-02-25 18:00:00.000000  None
# 923  433790  2023-02-25 20:00:10.691024  2023-02-25 19:00:00.000000  None
# 924  433897  2023-02-25 21:00:10.674598  2023-02-25 20:00:00.000000  None
# 925  434004  2023-02-25 22:00:10.704659  2023-02-25 21:00:00.000000  None
#
#       min   max last_reset    state    sum  metadata_id
# 921  None  None       None  107.148  7.090           81
# 922  None  None       None  107.148  7.090           81
# 923  None  None       None  107.148  7.090           81
# 924  None  None       None  107.148  7.090           81
# 925  None  None       None  107.149  7.091           81
# <div>                            <div id="8c60c039-0c3e-494b-a832-ef9a8a2ee100" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c60c039-0c3e-494b-a832-ef9a8a2ee100")) {                    Plotly.newPlot(                        "8c60c039-0c3e-494b-a832-ef9a8a2ee100",                        [{"hovertemplate":"variable=state<br>start=%{x}<br>value=%{y}<extra></extra>","legendgroup":"state","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"state","showlegend":true,"x":["2022-11-29 17:00:00.000000","2022-11-29 18:00:00.000000","2022-11-29 19:00:00.000000","2022-11-29 20:00:00.000000","2022-11-29 21:00:00.000000","2022-11-30 00:00:00.000000","2022-11-30 01:00:00.000000","2022-11-30 02:00:00.000000","2022-11-30 03:00:00.000000","2022-11-30 04:00:00.000000","2022-11-30 05:00:00.000000","2022-11-30 06:00:00.000000","2022-11-30 07:00:00.000000","2022-11-30 08:00:00.000000","2022-11-30 09:00:00.000000","2022-11-30 10:00:00.000000","2022-11-30 11:00:00.000000","2022-11-30 12:00:00.000000","2022-11-30 13:00:00.000000","2022-11-30 14:00:00.000000","2022-11-30 15:00:00.000000","2022-11-30 16:00:00.000000","2022-11-30 17:00:00.000000","2022-11-30 18:00:00.000000","2022-11-30 19:00:00.000000","2022-11-30 20:00:00.000000","2022-11-30 21:00:00.000000","2022-11-30 22:00:00.000000","2022-11-30 23:00:00.000000","2022-12-01 00:00:00.000000","2022-12-01 01:00:00.000000","2022-12-01 02:00:00.000000","2022-12-01 03:00:00.000000","2022-12-01 04:00:00.000000","2022-12-01 05:00:00.000000","2022-12-01 06:00:00.000000","2022-12-01 07:00:00.000000","2022-12-01 08:00:00.000000","2022-12-01 09:00:00.000000","2022-12-01 10:00:00.000000","2022-12-01 11:00:00.000000","2022-12-01 12:00:00.000000","2022-12-01 13:00:00.000000","2022-12-01 14:00:00.000000","2022-12-01 15:00:00.000000","2022-12-01 16:00:00.000000","2022-12-01 17:00:00.000000","2022-12-01 18:00:00.000000","2022-12-01 19:00:00.000000","2022-12-01 20:00:00.000000","2022-12-01 21:00:00.000000","2022-12-01 22:00:00.000000","2022-12-01 23:00:00.000000","2022-12-02 00:00:00.000000","2022-12-02 01:00:00.000000","2022-12-02 02:00:00.000000","2022-12-02 03:00:00.000000","2022-12-02 04:00:00.000000","2022-12-02 05:00:00.000000","2022-12-02 06:00:00.000000","2022-12-02 07:00:00.000000","2022-12-02 08:00:00.000000","2022-12-02 09:00:00.000000","2022-12-02 10:00:00.000000","2022-12-02 11:00:00.000000","2022-12-02 12:00:00.000000","2022-12-02 13:00:00.000000","2022-12-02 14:00:00.000000","2022-12-02 15:00:00.000000","2022-12-02 16:00:00.000000","2022-12-02 17:00:00.000000","2022-12-02 18:00:00.000000","2022-12-02 19:00:00.000000","2022-12-02 20:00:00.000000","2022-12-02 21:00:00.000000","2022-12-02 22:00:00.000000","2022-12-02 23:00:00.000000","2022-12-03 00:00:00.000000","2022-12-03 01:00:00.000000","2022-12-03 06:00:00.000000","2022-12-03 07:00:00.000000","2022-12-03 08:00:00.000000","2022-12-03 09:00:00.000000","2022-12-03 10:00:00.000000","2022-12-03 12:00:00.000000","2022-12-04 13:00:00.000000","2022-12-04 14:00:00.000000","2022-12-04 15:00:00.000000","2023-01-17 23:00:00.000000","2023-01-18 00:00:00.000000","2023-01-18 01:00:00.000000","2023-01-18 02:00:00.000000","2023-01-18 03:00:00.000000","2023-01-18 04:00:00.000000","2023-01-18 05:00:00.000000","2023-01-18 09:00:00.000000","2023-01-18 10:00:00.000000","2023-01-18 11:00:00.000000","2023-01-18 12:00:00.000000","2023-01-18 13:00:00.000000","2023-01-18 14:00:00.000000","2023-01-18 15:00:00.000000","2023-01-18 16:00:00.000000","2023-01-18 17:00:00.000000","2023-01-18 18:00:00.000000","2023-01-18 19:00:00.000000","2023-01-18 20:00:00.000000","2023-01-18 21:00:00.000000","2023-01-18 22:00:00.000000","2023-01-18 23:00:00.000000","2023-01-19 00:00:00.000000","2023-01-19 01:00:00.000000 ...
#            id                     created                       start  mean  \
# 5436  4259656  2023-02-25 21:40:10.663924  2023-02-25 21:35:00.000000  None
# 5437  4259763  2023-02-25 21:45:10.671089  2023-02-25 21:40:00.000000  None
# 5438  4259870  2023-02-25 21:50:10.633405  2023-02-25 21:45:00.000000  None
# 5439  4259977  2023-02-25 21:55:10.635846  2023-02-25 21:50:00.000000  None
# 5440  4260084  2023-02-25 22:00:10.659872  2023-02-25 21:55:00.000000  None
#
#        min   max last_reset    state    sum  metadata_id
# 5436  None  None       None  107.148  7.090           81
# 5437  None  None       None  107.148  7.090           81
# 5438  None  None       None  107.148  7.090           81
# 5439  None  None       None  107.149  7.091           81
# 5440  None  None       None  107.149  7.091           81
# <div>                            <div id="c893cb8b-30d4-4d6e-ad65-d0120df274cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c893cb8b-30d4-4d6e-ad65-d0120df274cc")) {                    Plotly.newPlot(                        "c893cb8b-30d4-4d6e-ad65-d0120df274cc",                        [{"hovertemplate":"variable=state<br>start=%{x}<br>value=%{y}<extra></extra>","legendgroup":"state","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"state","showlegend":true,"x":["2023-02-06 03:15:00.000000","2023-02-06 03:25:00.000000","2023-02-06 03:30:00.000000","2023-02-06 03:35:00.000000","2023-02-06 03:40:00.000000","2023-02-06 03:45:00.000000","2023-02-06 03:50:00.000000","2023-02-06 03:55:00.000000","2023-02-06 04:00:00.000000","2023-02-06 04:05:00.000000","2023-02-06 04:35:00.000000","2023-02-06 04:40:00.000000","2023-02-06 04:50:00.000000","2023-02-06 04:55:00.000000","2023-02-06 05:00:00.000000","2023-02-06 05:05:00.000000","2023-02-06 05:10:00.000000","2023-02-06 05:20:00.000000","2023-02-06 05:25:00.000000","2023-02-06 05:35:00.000000","2023-02-06 05:40:00.000000","2023-02-06 05:45:00.000000","2023-02-06 05:50:00.000000","2023-02-06 05:55:00.000000","2023-02-06 06:00:00.000000","2023-02-06 06:10:00.000000","2023-02-06 06:15:00.000000","2023-02-06 06:20:00.000000","2023-02-06 06:25:00.000000","2023-02-06 06:40:00.000000","2023-02-06 06:45:00.000000","2023-02-06 06:50:00.000000","2023-02-06 06:55:00.000000","2023-02-06 07:00:00.000000","2023-02-06 07:10:00.000000","2023-02-06 07:15:00.000000","2023-02-06 07:30:00.000000","2023-02-06 07:35:00.000000","2023-02-06 07:40:00.000000","2023-02-06 07:45:00.000000","2023-02-06 08:00:00.000000","2023-02-06 08:05:00.000000","2023-02-06 08:10:00.000000","2023-02-06 08:15:00.000000","2023-02-06 08:20:00.000000","2023-02-06 08:25:00.000000","2023-02-06 08:30:00.000000","2023-02-06 08:35:00.000000","2023-02-06 08:40:00.000000","2023-02-06 08:45:00.000000","2023-02-06 08:50:00.000000","2023-02-06 08:55:00.000000","2023-02-06 09:00:00.000000","2023-02-06 09:05:00.000000","2023-02-06 09:10:00.000000","2023-02-06 09:15:00.000000","2023-02-06 09:20:00.000000","2023-02-06 09:25:00.000000","2023-02-06 09:30:00.000000","2023-02-06 09:35:00.000000","2023-02-06 09:40:00.000000","2023-02-06 09:45:00.000000","2023-02-06 09:50:00.000000","2023-02-06 09:55:00.000000","2023-02-06 10:00:00.000000","2023-02-06 10:05:00.000000","2023-02-06 10:10:00.000000","2023-02-06 10:15:00.000000","2023-02-06 10:20:00.000000","2023-02-06 10:25:00.000000","2023-02-06 10:30:00.000000","2023-02-06 10:35:00.000000","2023-02-06 10:40:00.000000","2023-02-06 10:45:00.000000","2023-02-06 10:50:00.000000","2023-02-06 10:55:00.000000","2023-02-06 11:00:00.000000","2023-02-06 11:05:00.000000","2023-02-06 11:10:00.000000","2023-02-06 11:20:00.000000","2023-02-06 11:25:00.000000","2023-02-06 11:30:00.000000","2023-02-06 11:35:00.000000","2023-02-06 11:40:00.000000","2023-02-06 11:45:00.000000","2023-02-06 11:50:00.000000","2023-02-06 11:55:00.000000","2023-02-06 12:00:00.000000","2023-02-06 12:05:00.000000","2023-02-06 12:10:00.000000","2023-02-06 12:15:00.000000","2023-02-06 12:20:00.000000","2023-02-06 12:25:00.000000","2023-02-06 12:30:00.000000","2023-02-06 12:35:00.000000","2023-02-06 12:40:00.000000","2023-02-06 12:45:00.000000","2023-02-06 12:50:00.000000","2023-02-06 12:55:00.000000","2023-02-06 13:00:00.000000","2023-02-06 13:05:00.000000","2023-02-06 13:10:00.000000","2023-02-06 13:15:00.000000","2023-02-06 13:20:00.000000","2023-02-06 13:25:00.000000","2023-02-06 13:30:00.000000","2023-02-06 13:35:00.000000","2023-02-06 13:40:00.000000","2023-02-06 13:45:00.000000","2023-02-06 13:50:00.000000","2023-02-06 13:55:00.000000","2023-02-06 14:00:00.000000 ...

# %% [markdown]
# # Copy db back to home assistant server

# %%
! scp home-assistant_v2.db homeassistant@{hass_ip}:/home/homeassistant/.homeassistant/
# Out:
# home-assistant_v2.db                          100%  590MB   9.2MB/s   01:04
